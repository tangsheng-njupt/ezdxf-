# %%
import ezdxf
from ezdxf.layouts import Modelspace
# 创建一个新的DXF图纸
doc = ezdxf.new()
# 获取modelspace，这是我们将添加线，形状和其他实体的地方
msp = doc.modelspace()
# 步骤2
points1 = [(0,0), (6000,0), (6000,9000), (0,9000)]
msp.add_lwpolyline(points1)
# 步骤3
points2 = [(0,-380), (5200,-380), (5500,-580), (6500,-580), (6500,-680), (5500,-680), (5200,-480), (0,-480)]
msp.add_lwpolyline(points2)
# 步骤4
points3 = [(0,0), (6400,0), (6400,-580)]
msp.add_lwpolyline(points3)
# 步骤5
msp.add_line((0, -800), (0, 9800))
# 步骤6, 首先定义一个矩阵来进行反射变换
mat = ezdxf.math.Matrix44.scale(sx=-1)
for entity in msp:
    entity.transform(mat)
# 步骤7
hatch = msp.add_hatch(color=5)
hatch.set_pattern_fill('AR-B816', scale=5)

# 添加第一条标注
dim1 = msp.add_linear_dim(
    base=(500, 0),  # 尺寸线的基线位置
    p1=(0, 0),      # 尺寸起点
    p2=(0, -9000),   # 尺寸终点
    angle=90,       # 尺寸线的角度
    override={
        'dimtxt:': 100,          #文字高度
        'dimtxsty': 'Standard',  # 使用标准文本样式
        'dimclrd': 1,            # 尺寸线颜色
        'dimclre': 1,            # 尺寸界线颜色
        'dimclrt': 1,            # 尺寸文本颜色
        }
)
dim1.render()

# 添加第二条标注
dim2 = msp.add_linear_dim(
    base=(0, -9500),  # 尺寸线的基线位置
    p1=(0, -9000),      # 尺寸起点
    p2=(-6000, -9000),   # 尺寸终点
       override={
        'dimtxt:': 100,          #文字高度
        'dimtxsty': 'Standard',  # 使用标准文本样式
        'dimclrd': 1,            # 尺寸线颜色
        'dimclre': 1,            # 尺寸界线颜色
        'dimclrt': 1,            # 尺寸文本颜色
            }
)
dim2.render()

# 添加第三条标注
dim3 = msp.add_linear_dim(
    base=(500, 0),  # 尺寸线的基线位置
    p1=(0, 0),      # 尺寸起点
    p2=(0, 380),   # 尺寸终点
    angle=90,       # 尺寸线的角度
       override={
        'dimtxt:': 100,          #文字高度
        'dimtxsty': 'Standard',  # 使用标准文本样式
        'dimclrd': 1,            # 尺寸线颜色
        'dimclre': 1,            # 尺寸界线颜色
        'dimclrt': 1,            # 尺寸文本颜色
            }
)
dim3.render()

# 添加第四条标注
dim4 = msp.add_linear_dim(
    base=(500, 0),  # 尺寸线的基线位置
    p1=(0, 380),      # 尺寸起点
    p2=(0, 480),   # 尺寸终点
    angle=90,       # 尺寸线的角度
       override={
        'dimtxt:': 100,          #文字高度
        'dimtxsty': 'Standard',  # 使用标准文本样式
        'dimclrd': 1,            # 尺寸线颜色
        'dimclre': 1,            # 尺寸界线颜色
        'dimclrt': 1,            # 尺寸文本颜色
            }
)
dim4.render()

# 添加第五条标注
dim5 = msp.add_linear_dim(
    base=(0, 780),  # 尺寸线的基线位置
    p1=(0, 480),      # 尺寸起点
    p2=(-5200, 480),   # 尺寸终点
       override={
        'dimtxt:': 100,          #文字高度
        'dimtxsty': 'Standard',  # 使用标准文本样式
        'dimclrd': 1,            # 尺寸线颜色
        'dimclre': 1,            # 尺寸界线颜色
        'dimclrt': 1,            # 尺寸文本颜色
            }
)
dim5.render()

# 添加第六条标注
dim6 = msp.add_linear_dim(
    base=(4900, 780),  # 尺寸线的基线位置
    p1=(-5500, 680),      # 尺寸起点
    p2=(-6500, 680),   # 尺寸终点       
       override={
        'dimtxt:': 100,          #文字高度
        'dimtxsty': 'Standard',  # 使用标准文本样式
        'dimclrd': 1,            # 尺寸线颜色
        'dimclre': 1,            # 尺寸界线颜色
        'dimclrt': 1,            # 尺寸文本颜色
            }
)
dim6.render()

# 添加第七条标注
dim7 = msp.add_linear_dim(
    base=(-6600, 0),  # 尺寸线的基线位置
    p1=(-6500, 680),      # 尺寸起点
    p2=(-6500, 580),   # 尺寸终点
    angle=90,       # 尺寸线的角度
       override={
        'dimtxt:': 100,          #文字高度
        'dimtxsty': 'Standard',  # 使用标准文本样式
        'dimclrd': 1,            # 尺寸线颜色
        'dimclre': 1,            # 尺寸界线颜色
        'dimclrt': 1,            # 尺寸文本颜色
            }
)
dim7.render()

# 添加第八条标注
dim8 = msp.add_linear_dim(
    base=(-6600, 480),  # 尺寸线的基线位置
    p1=(-6500, 580),      # 尺寸起点
    p2=(-6400, 580),   # 尺寸终点
       override={
        'dimtxt:': 100,          #文字高度
        'dimtxsty': 'Standard',  # 使用标准文本样式
        'dimclrd': 1,            # 尺寸线颜色
        'dimclre': 1,            # 尺寸界线颜色
        'dimclrt': 1,            # 尺寸文本颜色
            }
)
dim8.render()

# 添加第九条标注
dim9 = msp.add_linear_dim(
    base=(-6600, 0),  # 尺寸线的基线位置
    p1=(-6400, 580),      # 尺寸起点
    p2=(-6400, 0),   # 尺寸终点
    angle=90,       # 尺寸线的角度
       override={
        'dimtxt:': 100,          #文字高度
        'dimtxsty': 'Standard',  # 使用标准文本样式
        'dimclrd': 1,            # 尺寸线颜色
        'dimclre': 1,            # 尺寸界线颜色
        'dimclrt': 1,            # 尺寸文本颜色
            }
)
dim9.render()

# 添加第十条标注
dim10 = msp.add_linear_dim(
    base=(-6600, -200),  # 尺寸线的基线位置
    p1=(-6400, 0),      # 尺寸起点
    p2=(-6000, 0),   # 尺寸终点
       override={
        'dimtxt:': 100,          #文字高度
        'dimtxsty': 'Standard',  # 使用标准文本样式
        'dimclrd': 1,            # 尺寸线颜色
        'dimclre': 1,            # 尺寸界线颜色
        'dimclrt': 1,            # 尺寸文本颜色
            }
)
dim10.render()

doc.saveas('your_drawing.dxf')
